# %%
# JSON Lines Content Type Sampler
# This notebook collects samples of each unique content_type from a JSON Lines file

import json
import os
from pathlib import Path
from collections import defaultdict

# Configuration
INPUT_FILE = r"G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\jstor_metadata_2025-05-28.jsonl"  # Replace with your JSON Lines file path
OUTPUT_DIR = r"G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\content_type_samples"  # Directory to save individual JSON files
SAMPLES_PER_TYPE = 10  # Number of samples to collect per content_type
MIN_LINE_GAP = 500  # Minimum lines between samples of same content_type (for variety)

def collect_content_type_samples(input_file, output_dir, samples_per_type=3, min_line_gap=100):
    """
    Collect samples of each unique content_type from a JSON Lines file.
    Ensures samples are spread out (not consecutive) for better variety.
    
    Args:
        input_file (str): Path to the input JSON Lines file
        output_dir (str): Directory to save the sample JSON files
        samples_per_type (int): Number of samples to collect per content_type
        min_line_gap (int): Minimum number of lines between samples of the same content_type
    """
    
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Dictionary to track samples by content_type
    content_type_samples = defaultdict(list)
    content_type_counts = defaultdict(int)
    content_type_last_sample_line = defaultdict(int)  # Track last sampled line for each type
    
    total_lines = 0
    valid_lines = 0
    
    print("🔍 Scanning file for content types...")
    print(f"📏 Ensuring minimum {min_line_gap} line gap between samples of same type")
    
    try:
        with open(input_file, 'r', encoding='utf-8') as f:
            for line_num, line in enumerate(f, 1):
                total_lines += 1
                
                # Skip empty lines
                line = line.strip()
                if not line:
                    continue
                
                try:
                    # Parse the JSON line
                    json_data = json.loads(line)
                    valid_lines += 1
                    
                    # Get content_type
                    content_type = json_data.get('content_type', 'unknown')
                    content_type_counts[content_type] += 1
                    
                    # Check if we need more samples for this type
                    current_samples = len(content_type_samples[content_type])
                    if current_samples < samples_per_type:
                        # Check if enough lines have passed since last sample of this type
                        last_sample_line = content_type_last_sample_line[content_type]
                        line_gap = line_num - last_sample_line
                        
                        if line_gap >= min_line_gap or current_samples == 0:
                            content_type_samples[content_type].append({
                                'line_num': line_num,
                                'data': json_data
                            })
                            content_type_last_sample_line[content_type] = line_num
                            
                            print(f"📝 Collected sample {len(content_type_samples[content_type])}/{samples_per_type} for '{content_type}' (line {line_num}, gap: {line_gap})")
                    
                    # Check if we have enough samples for all discovered types
                    if line_num % 10000 == 0:
                        incomplete_types = sum(1 for samples in content_type_samples.values() if len(samples) < samples_per_type)
                        print(f"⏳ Processed {line_num:,} lines... Found {len(content_type_counts)} content types, {incomplete_types} still need more samples")
                        
                except json.JSONDecodeError as e:
                    print(f"⚠ Warning: Line {line_num} is not valid JSON - {e}")
                    continue
                    
    except FileNotFoundError:
        print(f"❌ Error: Input file '{input_file}' not found.")
        return False
    except Exception as e:
        print(f"❌ Error reading file: {e}")
        return False
    
    # Save samples to individual files
    print(f"\n💾 Saving samples to files...")
    total_saved = 0
    
    for content_type, samples in content_type_samples.items():
        for i, sample in enumerate(samples, 1):
            # Create safe filename from content_type
            safe_content_type = "".join(c if c.isalnum() or c in "._-" else "_" for c in content_type)
            output_filename = f"{safe_content_type}_sample_{i:02d}_line_{sample['line_num']:06d}.json"
            output_path = os.path.join(output_dir, output_filename)
            
            # Write to individual JSON file with pretty formatting
            with open(output_path, 'w', encoding='utf-8') as out_f:
                json.dump(sample['data'], out_f, indent=2, ensure_ascii=False)
            
            total_saved += 1
    
    # Print summary
    print(f"\n📊 SUMMARY")
    print(f"=" * 60)
    print(f"Total lines processed: {total_lines:,}")
    print(f"Valid JSON lines: {valid_lines:,}")
    print(f"Unique content types found: {len(content_type_counts)}")
    print(f"Sample files saved: {total_saved}")
    print(f"\nContent type distribution:")
    
    # Sort by count descending
    sorted_types = sorted(content_type_counts.items(), key=lambda x: x[1], reverse=True)
    for content_type, count in sorted_types:
        samples_collected = len(content_type_samples[content_type])
        print(f"  • {content_type}: {count:,} records ({samples_collected} samples collected)")
    
    return True, content_type_samples, content_type_counts

# Execute the content type sampling
print("JSON Lines Content Type Sampler")
print("=" * 50)
print(f"Input file: {INPUT_FILE}")
print(f"Output directory: {OUTPUT_DIR}")
print(f"Samples per content type: {SAMPLES_PER_TYPE}")
print(f"Minimum line gap between samples: {MIN_LINE_GAP}")
print()

# Run the sampling
result = collect_content_type_samples(INPUT_FILE, OUTPUT_DIR, SAMPLES_PER_TYPE, MIN_LINE_GAP)

if result and result[0]:  # Check if successful
    success, content_type_samples, content_type_counts = result
    
    # List the created files
    output_path = Path(OUTPUT_DIR)
    if output_path.exists():
        created_files = sorted(list(output_path.glob("*.json")))
        print(f"\n📁 Created sample files ({len(created_files)}):")
        
        # Group files by content type for better display
        files_by_type = defaultdict(list)
        for file_path in created_files:
            # Extract content type from filename
            filename = file_path.name
            content_type = filename.split('_sample_')[0]
            files_by_type[content_type].append(file_path)
        
        for content_type, files in sorted(files_by_type.items()):
            print(f"\n  {content_type}:")
            for file_path in files:
                file_size = file_path.stat().st_size
                print(f"    - {file_path.name} ({file_size:,} bytes)")

    # Display sample content from each content type
    print("\n" + "="*70)
    print("SAMPLE CONTENT - One example from each content type:")
    print("="*70)
    
    for content_type, samples in sorted(content_type_samples.items()):
        if samples:
            print(f"\n🏷️  CONTENT TYPE: {content_type}")
            print("-" * 50)
            
            # Show the first sample
            sample_data = samples[0]['data']
            
            # Show key fields for quick understanding
            key_fields = ['item_id', 'title', 'content_type', 'content_subtype', 'c5_data_type', 'published_date']
            for field in key_fields:
                if field in sample_data:
                    value = sample_data[field]
                    if isinstance(value, str) and len(value) > 100:
                        value = value[:100] + "..."
                    print(f"  {field}: {value}")
            
            print(f"  [From line {samples[0]['line_num']} of source file]")
    
    print(f"\n🎉 Complete! Collected samples of {len(content_type_samples)} different content types.")
    print(f"Check the '{OUTPUT_DIR}' directory for all sample files.")
# Out:
# JSON Lines Content Type Sampler
# ==================================================
# Input file: G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\jstor_metadata_2025-05-28.jsonl
# Output directory: G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\content_type_samples
# Samples per content type: 10
# Minimum line gap between samples: 500
#
# 🔍 Scanning file for content types...
# 📏 Ensuring minimum 500 line gap between samples of same type
# 📝 Collected sample 1/10 for 'contributed_content' (line 1, gap: 1)
# 📝 Collected sample 1/10 for 'research_report' (line 2, gap: 2)
# 📝 Collected sample 1/10 for 'multi_part_research_report_part' (line 5, gap: 5)
# 📝 Collected sample 1/10 for 'book' (line 39, gap: 39)
# 📝 Collected sample 1/10 for 'book_part' (line 40, gap: 40)
# 📝 Collected sample 1/10 for 'article' (line 215, gap: 215)
# 📝 Collected sample 2/10 for 'contributed_content' (line 501, gap: 500)
# 📝 Collected sample 2/10 for 'research_report' (line 518, gap: 516)
# 📝 Collected sample 1/10 for 'multi_part_research_report_parent' (line 533, gap: 533)
# 📝 Collected sample 2/10 for 'multi_part_research_report_part' (line 534, gap: 529)
# 📝 Collected sample 2/10 for 'book' (line 560, gap: 521)
# 📝 Collected sample 2/10 for 'book_part' (line 561, gap: 521)
# 📝 Collected sample 3/10 for 'contributed_content' (line 1001, gap: 500)
# 📝 Collected sample 3/10 for 'research_report' (line 1088, gap: 570)
# 📝 Collected sample 2/10 for 'multi_part_research_report_parent' (line 1111, gap: 578)
# 📝 Collected sample 3/10 for 'multi_part_research_report_part' (line 1112, gap: 578)
# 📝 Collected sample 3/10 for 'book' (line 1124, gap: 564)
# 📝 Collected sample 3/10 for 'book_part' (line 1125, gap: 564)
# 📝 Collected sample 4/10 for 'contributed_content' (line 1501, gap: 500)
# 📝 Collected sample 4/10 for 'research_report' (line 1634, gap: 546)
# 📝 Collected sample 4/10 for 'book' (line 1645, gap: 521)
# 📝 Collected sample 4/10 for 'book_part' (line 1646, gap: 521)
# 📝 Collected sample 3/10 for 'multi_part_research_report_parent' (line 1797, gap: 686)
# 📝 Collected sample 4/10 for 'multi_part_research_report_part' (line 1798, gap: 686)
# 📝 Collected sample 5/10 for 'contributed_content' (line 2001, gap: 500)
# 📝 Collected sample 5/10 for 'research_report' (line 2146, gap: 512)
# 📝 Collected sample 5/10 for 'book_part' (line 2185, gap: 539)
# 📝 Collected sample 5/10 for 'book' (line 2191, gap: 546)
# 📝 Collected sample 2/10 for 'article' (line 2216, gap: 2001)
# 📝 Collected sample 3/10 for 'article' (line 2716, gap: 500)
# 📝 Collected sample 4/10 for 'article' (line 3216, gap: 500)
# 📝 Collected sample 5/10 for 'article' (line 3716, gap: 500)
# 📝 Collected sample 6/10 for 'article' (line 4216, gap: 500)
# 📝 Collected sample 6/10 for 'research_report' (line 4633, gap: 2487)
# 📝 Collected sample 6/10 for 'book' (line 4635, gap: 2444)
# 📝 Collected sample 6/10 for 'book_part' (line 4636, gap: 2451)
# 📝 Collected sample 6/10 for 'contributed_content' (line 4723, gap: 2722)
# 📝 Collected sample 4/10 for 'multi_part_research_report_parent' (line 4834, gap: 3037)
# 📝 Collected sample 5/10 for 'multi_part_research_report_part' (line 4835, gap: 3037)
# 📝 Collected sample 7/10 for 'contributed_content' (line 5223, gap: 500)
# 📝 Collected sample 7/10 for 'research_report' (line 5314, gap: 681)
# 📝 Collected sample 7/10 for 'book' (line 5320, gap: 685)
# 📝 Collected sample 7/10 for 'book_part' (line 5321, gap: 685)
# 📝 Collected sample 5/10 for 'multi_part_research_report_parent' (line 5384, gap: 550)
# 📝 Collected sample 6/10 for 'multi_part_research_report_part' (line 5385, gap: 550)
# 📝 Collected sample 8/10 for 'book_part' (line 5821, gap: 500)
# 📝 Collected sample 8/10 for 'research_report' (line 5822, gap: 508)
# 📝 Collected sample 8/10 for 'book' (line 5838, gap: 518)
# 📝 Collected sample 8/10 for 'contributed_content' (line 5854, gap: 631)
# 📝 Collected sample 6/10 for 'multi_part_research_report_parent' (line 5885, gap: 501)
# 📝 Collected sample 7/10 for 'multi_part_research_report_part' (line 5886, gap: 501)
# 📝 Collected sample 7/10 for 'article' (line 5939, gap: 1723)
# 📝 Collected sample 9/10 for 'book_part' (line 6331, gap: 510)
# 📝 Collected sample 9/10 for 'contributed_content' (line 6354, gap: 500)
# 📝 Collected sample 9/10 for 'research_report' (line 6361, gap: 539)
# 📝 Collected sample 9/10 for 'book' (line 6363, gap: 525)
# 📝 Collected sample 8/10 for 'multi_part_research_report_part' (line 6474, gap: 588)
# 📝 Collected sample 8/10 for 'article' (line 6487, gap: 548)
# 📝 Collected sample 9/10 for 'article' (line 6987, gap: 500)
# 📝 Collected sample 10/10 for 'article' (line 7487, gap: 500)
# 📝 Collected sample 10/10 for 'contributed_content' (line 7710, gap: 1356)
# 📝 Collected sample 7/10 for 'multi_part_research_report_parent' (line 7715, gap: 1830)
# 📝 Collected sample 9/10 for 'multi_part_research_report_part' (line 7716, gap: 1242)
# 📝 Collected sample 10/10 for 'book' (line 8411, gap: 2048)
# 📝 Collected sample 10/10 for 'book_part' (line 8412, gap: 2081)
# 📝 Collected sample 10/10 for 'research_report' (line 8455, gap: 2094)
# 📝 Collected sample 8/10 for 'multi_part_research_report_parent' (line 8458, gap: 743)
# 📝 Collected sample 10/10 for 'multi_part_research_report_part' (line 8459, gap: 743)
# 📝 Collected sample 9/10 for 'multi_part_research_report_parent' (line 8966, gap: 508)
# 📝 Collected sample 10/10 for 'multi_part_research_report_parent' (line 9466, gap: 500)
# ⏳ Processed 10,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 20,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 30,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 40,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 50,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 60,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 70,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 80,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 90,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 100,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 110,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 120,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 130,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 140,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 150,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 160,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 170,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 180,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 190,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 200,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 210,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 220,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 230,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 240,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 250,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 260,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 270,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 280,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 290,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 300,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 310,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 320,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 330,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 340,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 350,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 360,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 370,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 380,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 390,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 400,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 410,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 420,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 430,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 440,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 450,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 460,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 470,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 480,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 490,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 500,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 510,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 520,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 530,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 540,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 550,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 560,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 570,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 580,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 590,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 600,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 610,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 620,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 630,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 640,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 650,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 660,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 670,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 680,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 690,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 700,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 710,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 720,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 730,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 740,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 750,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 760,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 770,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 780,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 790,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 800,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 810,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 820,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 830,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 840,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 850,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 860,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 870,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 880,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 890,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 900,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 910,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 920,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 930,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 940,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 950,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 960,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 970,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 980,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 990,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,000,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,010,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,020,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,030,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,040,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,050,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,060,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,070,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,080,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,090,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,100,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,110,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,120,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,130,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,140,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,150,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,160,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,170,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,180,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,190,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,200,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,210,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,220,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,230,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,240,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,250,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,260,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,270,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,280,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,290,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,300,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,310,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,320,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,330,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,340,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,350,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,360,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,370,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,380,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,390,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,400,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,410,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,420,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,430,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,440,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,450,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,460,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,470,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,480,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,490,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,500,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,510,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,520,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,530,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,540,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,550,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,560,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,570,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,580,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,590,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,600,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,610,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,620,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,630,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,640,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,650,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,660,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,670,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,680,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,690,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,700,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,710,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,720,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,730,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,740,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,750,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,760,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,770,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,780,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,790,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,800,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,810,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,820,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,830,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,840,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,850,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,860,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,870,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,880,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,890,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,900,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,910,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,920,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,930,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,940,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,950,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,960,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,970,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,980,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 1,990,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,000,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,010,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,020,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,030,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,040,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,050,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,060,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,070,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,080,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,090,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,100,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,110,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,120,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,130,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,140,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,150,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,160,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,170,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,180,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,190,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,200,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,210,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,220,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,230,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,240,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,250,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,260,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,270,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,280,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,290,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,300,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,310,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,320,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,330,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,340,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,350,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,360,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,370,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,380,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,390,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,400,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,410,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,420,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,430,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,440,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,450,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,460,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,470,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,480,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,490,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,500,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,510,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,520,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,530,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,540,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,550,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,560,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,570,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,580,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,590,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,600,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,610,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,620,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,630,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,640,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,650,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,660,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,670,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,680,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,690,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,700,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,710,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,720,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,730,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,740,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,750,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,760,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,770,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,780,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,790,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,800,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,810,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,820,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,830,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,840,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,850,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,860,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,870,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,880,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,890,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,900,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,910,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,920,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,930,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,940,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,950,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,960,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,970,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,980,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 2,990,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,000,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,010,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,020,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,030,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,040,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,050,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,060,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,070,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,080,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,090,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,100,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,110,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,120,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,130,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,140,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,150,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,160,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,170,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,180,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,190,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,200,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,210,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,220,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,230,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,240,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,250,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,260,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,270,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,280,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,290,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,300,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,310,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,320,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,330,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,340,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,350,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,360,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,370,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,380,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,390,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,400,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,410,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,420,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,430,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,440,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,450,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,460,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,470,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,480,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,490,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,500,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,510,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,520,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,530,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,540,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,550,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,560,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,570,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,580,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,590,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,600,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,610,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,620,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,630,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,640,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,650,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,660,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,670,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,680,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,690,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,700,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,710,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,720,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,730,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,740,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,750,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,760,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,770,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,780,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,790,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,800,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,810,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,820,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,830,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,840,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,850,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,860,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,870,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,880,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,890,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,900,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,910,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,920,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,930,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,940,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,950,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,960,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,970,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,980,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 3,990,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,000,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,010,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,020,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,030,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,040,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,050,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,060,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,070,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,080,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,090,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,100,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,110,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,120,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,130,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,140,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,150,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,160,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,170,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,180,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,190,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,200,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,210,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,220,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,230,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,240,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,250,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,260,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,270,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,280,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,290,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,300,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,310,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,320,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,330,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,340,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,350,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,360,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,370,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,380,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,390,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,400,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,410,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,420,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,430,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,440,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,450,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,460,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,470,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,480,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,490,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,500,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,510,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,520,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,530,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,540,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,550,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,560,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,570,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,580,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,590,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,600,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,610,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,620,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,630,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,640,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,650,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,660,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,670,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,680,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,690,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,700,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,710,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,720,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,730,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,740,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,750,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,760,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,770,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,780,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,790,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,800,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,810,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,820,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,830,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,840,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,850,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,860,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,870,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,880,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,890,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,900,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,910,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,920,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,930,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,940,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,950,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,960,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,970,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,980,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 4,990,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,000,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,010,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,020,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,030,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,040,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,050,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,060,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,070,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,080,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,090,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,100,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,110,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,120,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,130,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,140,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,150,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,160,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,170,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,180,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,190,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,200,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,210,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,220,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,230,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,240,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,250,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,260,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,270,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,280,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,290,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,300,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,310,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,320,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,330,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,340,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 5,350,000 lines... Found 7 content types, 0 still need more samples
# ...
# ⏳ Processed 12,030,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,040,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,050,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,060,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,070,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,080,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,090,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,100,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,110,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,120,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,130,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,140,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,150,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,160,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,170,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,180,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,190,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,200,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,210,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,220,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,230,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,240,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,250,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,260,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,270,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,280,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,290,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,300,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,310,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,320,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,330,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,340,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,350,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,360,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,370,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,380,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,390,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,400,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,410,000 lines... Found 7 content types, 0 still need more samples
# ⏳ Processed 12,420,000 lines... Found 7 content types, 0 still need more samples
#
# 💾 Saving samples to files...
#
# 📊 SUMMARY
# ============================================================
# Total lines processed: 12,424,726
# Valid JSON lines: 12,424,726
# Unique content types found: 7
# Sample files saved: 70
#
# Content type distribution:
#   • article: 11,683,423 records (10 samples collected)
#   • multi_part_research_report_part: 286,995 records (10 samples collected)
#   • book_part: 249,890 records (10 samples collected)
#   • contributed_content: 121,839 records (10 samples collected)
#   • research_report: 46,627 records (10 samples collected)
#   • multi_part_research_report_parent: 22,158 records (10 samples collected)
#   • book: 13,794 records (10 samples collected)
#
# 📁 Created sample files (142):
#
#   article:
#     - article_sample_01_line_000215.json (1,306 bytes)
#     - article_sample_02_line_000216.json (1,346 bytes)
#     - article_sample_02_line_000315.json (1,268 bytes)
#     - article_sample_02_line_002216.json (2,379 bytes)
#     - article_sample_03_line_000217.json (1,112 bytes)
#     - article_sample_03_line_000415.json (1,245 bytes)
#     - article_sample_03_line_002716.json (1,073 bytes)
#     - article_sample_04_line_000218.json (1,155 bytes)
#     - article_sample_04_line_003216.json (1,438 bytes)
#     - article_sample_05_line_000219.json (1,287 bytes)
#     - article_sample_05_line_003716.json (1,246 bytes)
#     - article_sample_06_line_000220.json (1,281 bytes)
#     - article_sample_06_line_004216.json (1,431 bytes)
#     - article_sample_07_line_000221.json (1,279 bytes)
#     - article_sample_07_line_005939.json (1,184 bytes)
#     - article_sample_08_line_000222.json (1,152 bytes)
#     - article_sample_08_line_006487.json (1,223 bytes)
#     - article_sample_09_line_000223.json (1,263 bytes)
#     - article_sample_09_line_006987.json (1,022 bytes)
#     - article_sample_10_line_000224.json (1,261 bytes)
#     - article_sample_10_line_007487.json (1,197 bytes)
#
#   book:
#     - book_sample_01_line_000039.json (1,208 bytes)
#     - book_sample_02_line_000070.json (1,407 bytes)
#     - book_sample_02_line_000141.json (1,738 bytes)
#     - book_sample_02_line_000560.json (1,370 bytes)
#     - book_sample_03_line_000096.json (2,074 bytes)
#     - book_sample_03_line_000560.json (1,370 bytes)
#     - book_sample_03_line_001124.json (1,409 bytes)
#     - book_sample_04_line_000141.json (1,738 bytes)
#     - book_sample_04_line_001645.json (1,480 bytes)
#     - book_sample_05_line_000164.json (1,490 bytes)
#     - book_sample_05_line_002191.json (1,446 bytes)
#     - book_sample_06_line_000560.json (1,370 bytes)
#     - book_sample_06_line_004635.json (1,432 bytes)
#     - book_sample_07_line_000680.json (1,365 bytes)
#     - book_sample_07_line_005320.json (1,269 bytes)
#     - book_sample_08_line_000733.json (1,357 bytes)
#     - book_sample_08_line_005838.json (1,296 bytes)
#     - book_sample_09_line_000842.json (1,629 bytes)
#     - book_sample_09_line_006363.json (1,614 bytes)
#     - book_sample_10_line_001124.json (1,409 bytes)
#     - book_sample_10_line_008411.json (1,349 bytes)
#
#   book_part:
#     - book_part_sample_01_line_000040.json (1,247 bytes)
#     - book_part_sample_02_line_000041.json (1,218 bytes)
#     - book_part_sample_02_line_000140.json (2,154 bytes)
#     - book_part_sample_02_line_000561.json (1,363 bytes)
#     - book_part_sample_03_line_000042.json (1,319 bytes)
#     - book_part_sample_03_line_000561.json (1,363 bytes)
#     - book_part_sample_03_line_001125.json (1,322 bytes)
#     - book_part_sample_04_line_000043.json (1,239 bytes)
#     - book_part_sample_04_line_001646.json (1,571 bytes)
#     - book_part_sample_05_line_000044.json (1,230 bytes)
#     - book_part_sample_05_line_002185.json (1,522 bytes)
#     - book_part_sample_06_line_000045.json (1,216 bytes)
#     - book_part_sample_06_line_004636.json (1,394 bytes)
#     - book_part_sample_07_line_000046.json (1,211 bytes)
#     - book_part_sample_07_line_005321.json (1,243 bytes)
#     - book_part_sample_08_line_000047.json (1,207 bytes)
#     - book_part_sample_08_line_005821.json (1,586 bytes)
#     - book_part_sample_09_line_000048.json (1,216 bytes)
#     - book_part_sample_09_line_006331.json (1,245 bytes)
#     - book_part_sample_10_line_000049.json (1,309 bytes)
#     - book_part_sample_10_line_008412.json (1,473 bytes)
#
#   contributed_content:
#     - contributed_content_sample_01_line_000001.json (1,010 bytes)
#     - contributed_content_sample_02_line_000065.json (1,049 bytes)
#     - contributed_content_sample_02_line_000160.json (1,356 bytes)
#     - contributed_content_sample_02_line_000501.json (1,164 bytes)
#     - contributed_content_sample_03_line_000066.json (1,137 bytes)
#     - contributed_content_sample_03_line_000463.json (1,140 bytes)
#     - contributed_content_sample_03_line_001001.json (1,086 bytes)
#     - contributed_content_sample_04_line_000067.json (1,143 bytes)
#     - contributed_content_sample_04_line_001501.json (1,138 bytes)
#     - contributed_content_sample_05_line_000068.json (1,143 bytes)
#     - contributed_content_sample_05_line_002001.json (1,232 bytes)
#     - contributed_content_sample_06_line_000069.json (1,147 bytes)
#     - contributed_content_sample_06_line_004723.json (1,017 bytes)
#     - contributed_content_sample_07_line_000086.json (1,083 bytes)
#     - contributed_content_sample_07_line_005223.json (1,330 bytes)
#     - contributed_content_sample_08_line_000087.json (1,083 bytes)
#     - contributed_content_sample_08_line_005854.json (1,122 bytes)
#     - contributed_content_sample_09_line_000088.json (1,034 bytes)
#     - contributed_content_sample_09_line_006354.json (1,013 bytes)
#     - contributed_content_sample_10_line_000089.json (1,034 bytes)
#     - contributed_content_sample_10_line_007710.json (1,501 bytes)
#
#   multi_part_research_report_parent:
#     - multi_part_research_report_parent_sample_01_line_000533.json (1,294 bytes)
#     - multi_part_research_report_parent_sample_02_line_001111.json (1,412 bytes)
#     - multi_part_research_report_parent_sample_03_line_001335.json (1,360 bytes)
#     - multi_part_research_report_parent_sample_03_line_001797.json (1,445 bytes)
#     - multi_part_research_report_parent_sample_04_line_001797.json (1,445 bytes)
#     - multi_part_research_report_parent_sample_04_line_004834.json (1,502 bytes)
#     - multi_part_research_report_parent_sample_05_line_002108.json (1,296 bytes)
#     - multi_part_research_report_parent_sample_05_line_005384.json (1,555 bytes)
#     - multi_part_research_report_parent_sample_06_line_002123.json (1,160 bytes)
#     - multi_part_research_report_parent_sample_06_line_005885.json (1,273 bytes)
#     - multi_part_research_report_parent_sample_07_line_002135.json (1,825 bytes)
#     - multi_part_research_report_parent_sample_07_line_007715.json (1,397 bytes)
#     - multi_part_research_report_parent_sample_08_line_002147.json (1,551 bytes)
#     - multi_part_research_report_parent_sample_08_line_008458.json (1,283 bytes)
#     - multi_part_research_report_parent_sample_09_line_002161.json (1,148 bytes)
#     - multi_part_research_report_parent_sample_09_line_008966.json (1,209 bytes)
#     - multi_part_research_report_parent_sample_10_line_004834.json (1,502 bytes)
#     - multi_part_research_report_parent_sample_10_line_009466.json (1,405 bytes)
#
#   multi_part_research_report_part:
#     - multi_part_research_report_part_sample_01_line_000005.json (1,002 bytes)
#     - multi_part_research_report_part_sample_02_line_000006.json (1,003 bytes)
#     - multi_part_research_report_part_sample_02_line_000534.json (1,080 bytes)
#     - multi_part_research_report_part_sample_03_line_000007.json (1,001 bytes)
#     - multi_part_research_report_part_sample_03_line_001112.json (1,037 bytes)
#     - multi_part_research_report_part_sample_04_line_000008.json (1,003 bytes)
#     - multi_part_research_report_part_sample_04_line_001798.json (1,110 bytes)
#     - multi_part_research_report_part_sample_05_line_000009.json (1,003 bytes)
#     - multi_part_research_report_part_sample_05_line_004835.json (1,084 bytes)
#     - multi_part_research_report_part_sample_06_line_000010.json (1,003 bytes)
#     - multi_part_research_report_part_sample_06_line_005385.json (1,122 bytes)
#     - multi_part_research_report_part_sample_07_line_000011.json (1,004 bytes)
#     - multi_part_research_report_part_sample_07_line_005886.json (1,075 bytes)
#     - multi_part_research_report_part_sample_08_line_000012.json (1,103 bytes)
#     - multi_part_research_report_part_sample_08_line_006474.json (1,044 bytes)
#     - multi_part_research_report_part_sample_09_line_000013.json (1,022 bytes)
#     - multi_part_research_report_part_sample_09_line_007716.json (1,169 bytes)
#     - multi_part_research_report_part_sample_10_line_000014.json (1,073 bytes)
#     - multi_part_research_report_part_sample_10_line_008459.json (1,118 bytes)
#
#   research_report:
#     - research_report_sample_01_line_000002.json (911 bytes)
#     - research_report_sample_02_line_000003.json (911 bytes)
#     - research_report_sample_02_line_000212.json (1,221 bytes)
#     - research_report_sample_02_line_000518.json (1,362 bytes)
#     - research_report_sample_03_line_000004.json (911 bytes)
#     - research_report_sample_03_line_000518.json (1,362 bytes)
#     - research_report_sample_03_line_001088.json (1,352 bytes)
#     - research_report_sample_04_line_000212.json (1,221 bytes)
#     - research_report_sample_04_line_001634.json (1,298 bytes)
#     - research_report_sample_05_line_000518.json (1,362 bytes)
#     - research_report_sample_05_line_002146.json (1,250 bytes)
#     - research_report_sample_06_line_000767.json (1,195 bytes)
#     - research_report_sample_06_line_004633.json (1,194 bytes)
#     - research_report_sample_07_line_001088.json (1,352 bytes)
#     - research_report_sample_07_line_005314.json (1,624 bytes)
#     - research_report_sample_08_line_001148.json (1,289 bytes)
#     - research_report_sample_08_line_005822.json (1,361 bytes)
#     - research_report_sample_09_line_001292.json (1,458 bytes)
#     - research_report_sample_09_line_006361.json (1,137 bytes)
#     - research_report_sample_10_line_001299.json (1,240 bytes)
#     - research_report_sample_10_line_008455.json (1,261 bytes)
#
# ======================================================================
# SAMPLE CONTENT - One example from each content type:
# ======================================================================
#
# 🏷️  CONTENT TYPE: article
# --------------------------------------------------
#   item_id: 30627aa8-0f30-3c56-a168-00d190dbd281
#   title: "Make Sure You Gather up the Heads!" The Role of Women and Children on the Farm in the 1920's
#   content_type: article
#   content_subtype: research-article
#   c5_data_type: Journal
#   published_date: 2003-04-0
#   [From line 215 of source file]
#
# 🏷️  CONTENT TYPE: book
# --------------------------------------------------
#   item_id: d9a19a81-54fc-3fc1-93ec-6db8578d4df5
#   title: " . . . A Right Good People"
#   content_type: book
#   content_subtype: None
#   c5_data_type: Book
#   published_date: 1974-01-0
#   [From line 39 of source file]
#
# 🏷️  CONTENT TYPE: book_part
# --------------------------------------------------
#   item_id: 38671553-66b6-3a22-a90c-ae39f970917d
#   title: A FOOT-STOMPING JAM SESSION IN THE OLD GAS STATION
#   content_type: book_part
#   content_subtype: chapter
#   c5_data_type: Book
#   published_date: 1974-01-0
#   [From line 40 of source file]
#
# 🏷️  CONTENT TYPE: contributed_content
# --------------------------------------------------
#   item_id: 81e94608-c4dc-3e28-b08e-7efc0f19553c
#   title: None
#   content_type: contributed_content
#   content_subtype: contributed_content_documents
#   c5_data_type: Other
#   published_date: None
#   [From line 1 of source file]
#
# 🏷️  CONTENT TYPE: multi_part_research_report_parent
# --------------------------------------------------
#   item_id: 47ef68fb-07ad-3071-9dab-af72f1f0135b
#   title: "CONSENSUAL DEMOCRACY" IN POST-GENOCIDE RWANDA: EVALUATING THE MARCH 2001 DISTRICT ELECTIONS
#   content_type: multi_part_research_report_parent
#   content_subtype: Other
#   c5_data_type: Report
#   published_date: 2001-10-0
#   [From line 533 of source file]
#
# 🏷️  CONTENT TYPE: multi_part_research_report_part
# --------------------------------------------------
#   item_id: 3bd59245-4fdc-37a5-ad1d-fac00ed360b5
#   title: APPENDIX D – TABLE 3
#   content_type: multi_part_research_report_part
#   content_subtype: Other
#   c5_data_type: Report
#   published_date: 2011-01-0
#   [From line 5 of source file]
#
# 🏷️  CONTENT TYPE: research_report
# --------------------------------------------------
#   item_id: c78ba12f-c452-34f9-971d-41f7c92c029a
#   title: None
#   content_type: research_report
#   content_subtype: Other
#   c5_data_type: Report
#   published_date: 0001-01-0
#   [From line 2 of source file]
#
# 🎉 Complete! Collected samples of 7 different content types.
# Check the 'G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\content_type_samples' directory for all sample files.
