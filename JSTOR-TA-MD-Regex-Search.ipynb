# %%
# JSONL Title Regex Search
# This notebook searches through a JSONL file for items where the title matches a regular expression

import json
import re
import os
from pathlib import Path
from datetime import datetime

# Configuration
INPUT_FILE = r"G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\jstor_metadata_2025-05-28.jsonl"
OUTPUT_DIR = r"G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\regex_search_results"

def search_titles_regex(input_file, output_dir, regex_pattern, case_sensitive=False):
    """
    Search through JSONL file for titles matching a regular expression.
    
    Args:
        input_file (str): Path to the input JSON Lines file
        output_dir (str): Directory to save results
        regex_pattern (str): Regular expression pattern to search for
        case_sensitive (bool): Whether search should be case sensitive
    """
    
    # Create output directory if it doesn't exist
    Path(output_dir).mkdir(parents=True, exist_ok=True)
    
    # Compile regex pattern
    flags = 0 if case_sensitive else re.IGNORECASE
    try:
        compiled_regex = re.compile(regex_pattern, flags)
    except re.error as e:
        print(f"❌ Error: Invalid regular expression '{regex_pattern}' - {e}")
        return False
    
    # Initialize tracking variables
    total_lines = 0
    valid_json_lines = 0
    items_with_titles = 0
    matching_items = []
    sample_matches = []  # Store first few matches for display
    
    print(f"🔍 Searching for pattern: '{regex_pattern}'")
    print(f"📁 Case sensitive: {case_sensitive}")
    print(f"📄 Input file: {input_file}")
    print("=" * 70)
    
    try:
        with open(input_file, 'r', encoding='utf-8') as f:
            for line_num, line in enumerate(f, 1):
                total_lines += 1
                
                # Skip empty lines
                line = line.strip()
                if not line:
                    continue
                
                try:
                    # Parse the JSON line
                    json_data = json.loads(line)
                    valid_json_lines += 1
                    
                    # Get title field
                    title = json_data.get('title')
                    if title is not None:
                        items_with_titles += 1
                        
                        # Check if title matches regex
                        if compiled_regex.search(title):
                            item_id = json_data.get('item_id', f'unknown_line_{line_num}')
                            matching_items.append({
                                'item_id': item_id,
                                'title': title,
                                'line_num': line_num,
                                'content_type': json_data.get('content_type', 'unknown')
                            })
                            
                            # Store first few matches as samples
                            if len(sample_matches) < 10:
                                sample_matches.append({
                                    'item_id': item_id,
                                    'title': title,
                                    'line_num': line_num
                                })
                            
                            # Progress indicator for matches
                            if len(matching_items) % 100 == 0:
                                print(f"✅ Found {len(matching_items)} matches so far...")
                    
                    # Progress indicator for processing
                    if line_num % 50000 == 0:
                        print(f"⏳ Processed {line_num:,} lines... {len(matching_items)} matches found")
                        
                except json.JSONDecodeError as e:
                    print(f"⚠ Warning: Line {line_num} is not valid JSON - {e}")
                    continue
                    
    except FileNotFoundError:
        print(f"❌ Error: Input file '{input_file}' not found.")
        return False
    except Exception as e:
        print(f"❌ Error reading file: {e}")
        return False
    
    # Generate timestamp for output files
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    
    # Save item_ids to text file
    output_filename = f"matching_item_ids_{timestamp}.txt"
    output_path = os.path.join(output_dir, output_filename)
    
    try:
        with open(output_path, 'w', encoding='utf-8') as out_f:
            for item in matching_items:
                out_f.write(f"{item['item_id']}\n")
        
        print(f"\n💾 Saved {len(matching_items)} item IDs to: {output_filename}")
        
    except Exception as e:
        print(f"❌ Error saving results: {e}")
        return False
    
    # Print comprehensive summary
    print("\n" + "=" * 70)
    print("📊 SEARCH RESULTS SUMMARY")
    print("=" * 70)
    print(f"Regular expression: '{regex_pattern}'")
    print(f"Case sensitive: {case_sensitive}")
    print(f"Total lines processed: {total_lines:,}")
    print(f"Valid JSON lines: {valid_json_lines:,}")
    print(f"Items with non-null titles: {items_with_titles:,}")
    print(f"Items matching regex: {len(matching_items):,}")
    
    if items_with_titles > 0:
        match_percentage = (len(matching_items) / items_with_titles) * 100
        print(f"Match percentage: {match_percentage:.2f}% of items with titles")
    
    # Show content type breakdown of matches
    if matching_items:
        content_type_counts = {}
        for item in matching_items:
            content_type = item['content_type']
            content_type_counts[content_type] = content_type_counts.get(content_type, 0) + 1
        
        print(f"\n📋 Matches by content type:")
        sorted_types = sorted(content_type_counts.items(), key=lambda x: x[1], reverse=True)
        for content_type, count in sorted_types:
            print(f"  • {content_type}: {count:,} matches")
    
    # Show sample matches
    if sample_matches:
        print(f"\n🔍 Sample matches (first {len(sample_matches)}):")
        print("-" * 70)
        for i, match in enumerate(sample_matches, 1):
            title_preview = match['title'][:80] + "..." if len(match['title']) > 80 else match['title']
            print(f"{i:2d}. Line {match['line_num']:6d} | {match['item_id']}")
            print(f"     Title: {title_preview}")
            print()
    
    print(f"\n🎉 Search complete! Results saved to: {output_path}")
    
    return True, matching_items, output_path

# Interactive input for regex pattern
print("JSONL Title Regex Search Tool")
print("=" * 50)
print("This tool searches for titles matching a regular expression pattern.")
print("Examples:")
print("  - 'COVID.*vaccine' (COVID followed by vaccine)")
print("  - '^The ' (titles starting with 'The ')")
print("  - '\\d{4}' (contains a 4-digit number)")
print("  - 'climate.*change|global.*warming' (climate change OR global warming)")
print()

# Get user input
regex_pattern = input("Enter your regular expression pattern: ").strip()

if not regex_pattern:
    print("❌ No pattern entered. Exiting.")
else:
    # Ask about case sensitivity
    case_sensitive_input = input("Case sensitive search? (y/n, default=n): ").strip().lower()
    case_sensitive = case_sensitive_input in ['y', 'yes', 'true']
    
    print(f"\n🚀 Starting search with pattern: '{regex_pattern}'")
    
    # Run the search
    result = search_titles_regex(INPUT_FILE, OUTPUT_DIR, regex_pattern, case_sensitive)
    
    if result and result[0]:
        success, matching_items, output_file = result
        print(f"\n✨ Successfully found {len(matching_items)} matching items!")
        print(f"📄 Item IDs saved to: {output_file}")
    else:
        print("❌ Search failed or no results found.")
# Out:
# JSONL Title Regex Search Tool
# ==================================================
# This tool searches for titles matching a regular expression pattern.
# Examples:
#   - 'COVID.*vaccine' (COVID followed by vaccine)
#   - '^The ' (titles starting with 'The ')
#   - '\d{4}' (contains a 4-digit number)
#   - 'climate.*change|global.*warming' (climate change OR global warming)
# Enter your regular expression pattern:  foster care
# Case sensitive search? (y/n, default=n):  n
# 🚀 Starting search with pattern: 'foster care'
# 🔍 Searching for pattern: 'foster care'
# 📁 Case sensitive: False
# 📄 Input file: G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\jstor_metadata_2025-05-28.jsonl
# ⏳ Processed 5,900,000 lines... 370 matches found
# ⏳ Processed 5,950,000 lines... 370 matches found
# ⏳ Processed 6,000,000 lines... 370 matches found
# ⏳ Processed 6,050,000 lines... 370 matches found
# ⏳ Processed 6,100,000 lines... 370 matches found
# ⏳ Processed 6,150,000 lines... 375 matches found
# ⏳ Processed 6,200,000 lines... 375 matches found
# ⏳ Processed 6,250,000 lines... 375 matches found
# ⏳ Processed 6,300,000 lines... 375 matches found
# ⏳ Processed 6,350,000 lines... 377 matches found
# ⏳ Processed 6,400,000 lines... 378 matches found
# ⏳ Processed 6,450,000 lines... 378 matches found
# ⏳ Processed 6,500,000 lines... 378 matches found
# ⏳ Processed 6,550,000 lines... 378 matches found
# ⏳ Processed 6,600,000 lines... 378 matches found
# ⏳ Processed 6,650,000 lines... 378 matches found
# ⏳ Processed 6,700,000 lines... 380 matches found
# ⏳ Processed 6,750,000 lines... 380 matches found
# ⏳ Processed 6,800,000 lines... 380 matches found
# ⏳ Processed 6,850,000 lines... 380 matches found
# ⏳ Processed 6,900,000 lines... 381 matches found
# ⏳ Processed 6,950,000 lines... 382 matches found
# ⏳ Processed 7,000,000 lines... 382 matches found
# ⏳ Processed 7,050,000 lines... 383 matches found
# ⏳ Processed 7,100,000 lines... 383 matches found
# ⏳ Processed 7,150,000 lines... 383 matches found
# ⏳ Processed 7,200,000 lines... 385 matches found
# ⏳ Processed 7,250,000 lines... 385 matches found
# ⏳ Processed 7,300,000 lines... 385 matches found
# ⏳ Processed 7,350,000 lines... 385 matches found
# ⏳ Processed 7,400,000 lines... 386 matches found
# ⏳ Processed 7,450,000 lines... 386 matches found
# ⏳ Processed 7,500,000 lines... 386 matches found
# ⏳ Processed 7,550,000 lines... 386 matches found
# ⏳ Processed 7,600,000 lines... 386 matches found
# ⏳ Processed 7,650,000 lines... 386 matches found
# ⏳ Processed 7,700,000 lines... 386 matches found
# ⏳ Processed 7,750,000 lines... 386 matches found
# ⏳ Processed 7,800,000 lines... 386 matches found
# ⏳ Processed 7,850,000 lines... 386 matches found
# ⏳ Processed 7,900,000 lines... 386 matches found
# ⏳ Processed 7,950,000 lines... 386 matches found
# ⏳ Processed 8,000,000 lines... 386 matches found
# ⏳ Processed 8,050,000 lines... 386 matches found
# ⏳ Processed 8,100,000 lines... 386 matches found
# ⏳ Processed 8,150,000 lines... 386 matches found
# ⏳ Processed 8,200,000 lines... 386 matches found
# ⏳ Processed 8,250,000 lines... 386 matches found
# ⏳ Processed 8,300,000 lines... 386 matches found
# ⏳ Processed 8,350,000 lines... 386 matches found
# ⏳ Processed 8,400,000 lines... 386 matches found
# ✅ Found 400 matches so far...
# ⏳ Processed 8,450,000 lines... 421 matches found
# ⏳ Processed 8,500,000 lines... 422 matches found
# ⏳ Processed 8,550,000 lines... 423 matches found
# ⏳ Processed 8,600,000 lines... 424 matches found
# ⏳ Processed 8,650,000 lines... 424 matches found
# ⏳ Processed 8,700,000 lines... 424 matches found
# ⏳ Processed 8,750,000 lines... 425 matches found
# ⏳ Processed 8,800,000 lines... 425 matches found
# ⏳ Processed 8,850,000 lines... 425 matches found
# ⏳ Processed 8,900,000 lines... 426 matches found
# ⏳ Processed 8,950,000 lines... 426 matches found
# ⏳ Processed 9,000,000 lines... 426 matches found
# ⏳ Processed 9,050,000 lines... 426 matches found
# ⏳ Processed 9,100,000 lines... 426 matches found
# ⏳ Processed 9,150,000 lines... 426 matches found
# ⏳ Processed 9,200,000 lines... 426 matches found
# ⏳ Processed 9,250,000 lines... 426 matches found
# ⏳ Processed 9,300,000 lines... 426 matches found
# ⏳ Processed 9,350,000 lines... 426 matches found
# ⏳ Processed 9,400,000 lines... 427 matches found
# ⏳ Processed 9,450,000 lines... 427 matches found
# ⏳ Processed 9,500,000 lines... 427 matches found
# ⏳ Processed 9,550,000 lines... 427 matches found
# ⏳ Processed 9,600,000 lines... 427 matches found
# ⏳ Processed 9,650,000 lines... 427 matches found
# ⏳ Processed 9,700,000 lines... 427 matches found
# ⏳ Processed 9,750,000 lines... 427 matches found
# ⏳ Processed 9,800,000 lines... 428 matches found
# ⏳ Processed 9,850,000 lines... 428 matches found
# ⏳ Processed 9,900,000 lines... 428 matches found
# ⏳ Processed 9,950,000 lines... 428 matches found
# ⏳ Processed 10,000,000 lines... 428 matches found
# ⏳ Processed 10,050,000 lines... 428 matches found
# ⏳ Processed 10,100,000 lines... 428 matches found
# ⏳ Processed 10,150,000 lines... 428 matches found
# ⏳ Processed 10,200,000 lines... 432 matches found
# ⏳ Processed 10,250,000 lines... 433 matches found
# ⏳ Processed 10,300,000 lines... 434 matches found
# ⏳ Processed 10,350,000 lines... 434 matches found
# ⏳ Processed 10,400,000 lines... 434 matches found
# ⏳ Processed 10,450,000 lines... 435 matches found
# ⏳ Processed 10,500,000 lines... 436 matches found
# ⏳ Processed 10,550,000 lines... 436 matches found
# ⏳ Processed 10,600,000 lines... 437 matches found
# ⏳ Processed 10,650,000 lines... 438 matches found
# ⏳ Processed 10,700,000 lines... 438 matches found
# ⏳ Processed 10,750,000 lines... 439 matches found
# ⏳ Processed 10,800,000 lines... 440 matches found
# ⏳ Processed 10,850,000 lines... 440 matches found
# ⏳ Processed 10,900,000 lines... 440 matches found
# ⏳ Processed 10,950,000 lines... 441 matches found
# ⏳ Processed 11,000,000 lines... 441 matches found
# ⏳ Processed 11,050,000 lines... 442 matches found
# ⏳ Processed 11,100,000 lines... 442 matches found
# ⏳ Processed 11,150,000 lines... 442 matches found
# ⏳ Processed 11,200,000 lines... 442 matches found
# ⏳ Processed 11,250,000 lines... 442 matches found
# ⏳ Processed 11,300,000 lines... 442 matches found
# ⏳ Processed 11,350,000 lines... 443 matches found
# ⏳ Processed 11,400,000 lines... 443 matches found
# ⏳ Processed 11,450,000 lines... 443 matches found
# ⏳ Processed 11,500,000 lines... 443 matches found
# ⏳ Processed 11,550,000 lines... 444 matches found
# ⏳ Processed 11,600,000 lines... 444 matches found
# ⏳ Processed 11,650,000 lines... 445 matches found
# ⏳ Processed 11,700,000 lines... 446 matches found
# ⏳ Processed 11,750,000 lines... 446 matches found
# ⏳ Processed 11,800,000 lines... 446 matches found
# ⏳ Processed 11,850,000 lines... 447 matches found
# ⏳ Processed 11,900,000 lines... 447 matches found
# ⏳ Processed 11,950,000 lines... 447 matches found
# ⏳ Processed 12,000,000 lines... 447 matches found
# ⏳ Processed 12,050,000 lines... 447 matches found
# ⏳ Processed 12,100,000 lines... 447 matches found
# ⏳ Processed 12,150,000 lines... 448 matches found
# ⏳ Processed 12,200,000 lines... 448 matches found
# ⏳ Processed 12,250,000 lines... 448 matches found
# ⏳ Processed 12,300,000 lines... 448 matches found
# ⏳ Processed 12,350,000 lines... 448 matches found
# ⏳ Processed 12,400,000 lines... 448 matches found
#
# 💾 Saved 448 item IDs to: matching_item_ids_20250528_135901.txt
#
# ======================================================================
# 📊 SEARCH RESULTS SUMMARY
# ======================================================================
# Regular expression: 'foster care'
# Case sensitive: False
# Total lines processed: 12,424,726
# Valid JSON lines: 12,424,726
# Items with non-null titles: 12,424,643
# Items matching regex: 448
# Match percentage: 0.00% of items with titles
#
# 📋 Matches by content type:
#   • article: 439 matches
#   • research_report: 6 matches
#   • multi_part_research_report_parent: 3 matches
#
# 🔍 Sample matches (first 10):
# ----------------------------------------------------------------------
#  1. Line  16274 | 4ce7e492-b274-3402-bcdf-a0241801876b
#      Title: A Look at NextUp Implementation in California: Staff and Student Perspectives on...
#
#  2. Line  39212 | f234ae88-f494-3893-951b-3a04d727bb3c
#      Title: Boy Wants "Divorce" From Parents: Suit seeks to sever parental ties, pave the wa...
#
#  3. Line  41644 | f55b4a5f-061d-3bad-8506-e644fa553fd2
#      Title: FOSTER CARE LAWSUITS: States accused of failing to probe homes
#
#  4. Line  43842 | f4dda0a0-00a0-3377-a5ca-363633c519cf
#      Title: Kids' Stuff: Prospects brighten for improvements in foster care system
#
#  5. Line  51437 | e5187c98-32d9-3227-9c85-b3a4af3adab5
#      Title: WASHINGTON REPORT: Taking Out the Speed Bumps: Measure seeks to streamline proce...
#
#  6. Line 537342 | 6fbe66aa-9bbb-3767-bc77-6853e54fea4c
#      Title: An Uninsurable and Unavailable Foster Care System: How Lawsuits, Regulations, So...
#
#  7. Line 669882 | 6f3c3b30-58eb-37a0-913c-c5f4cbe0e629
#      Title: Somebody's Children or Nobody's Children? How the Sociological Perspective Could...
#
#  8. Line 678097 | 1f9f5734-cd41-3fce-b285-36ddec27231b
#      Title: Book Review : Fragile Families: Foster Care, Immigration, and Citizenship
#
#  9. Line 1082155 | 95741703-6541-3353-8abd-5fa0d40d85d3
#      Title: I’m a foster carer, please don’t call me mum
#
# 10. Line 1460344 | b1c41520-c4d5-34bd-ae0f-5e5896a918b8
#      Title: Analyzing Foster Care in New York City
#
#
# 🎉 Search complete! Results saved to: G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\regex_search_results\matching_item_ids_20250528_135901.txt
#
# ✨ Successfully found 448 matching items!
# 📄 Item IDs saved to: G:\Shared drives\Labs\Constellate\Constellate Sunset\JSTOR Text Mining\Examples\regex_search_results\matching_item_ids_20250528_135901.txt
